# %% [markdown]
# # GIN Classifier

# %% [markdown]
# ### Training

# %%
# !python /home/sxi219/RAI-Account/multi-stage-GNN-code-security/IPAG-GIN-CFEExplainer/src/ipag_gin/model/trainer.py \
  --src-base "/home/sxi219/RAI-Account/multi-stage-GNN-code-security/IPAG-GIN-CFEExplainer/data/graphs" \
  --cwe "CWE-119" \
  --cve-prefix "CVE" \
  --output-dir "./results" \
  --batch-size 32
# Out:
# ...
# GIN Vulnerability Classifier - BigVul Dataset
# ...
# Device: cuda
# Output Directory: results
#
#
# Loading and combining data directly from source...
# Source directory: /home/sxi219/RAI-Account/multi-stage-GNN-code-security/IPAG-GIN-CFEExplainer/data/graphs/CWE-119
#
# Processing CVE directories: 100%|█████████████| 637/637 [04:28<00:00,  2.38it/s]
#
# ✓ Loaded 559 positive samples
# ✓ Loaded 553 negative samples
# ✓ Total samples: 1112
#
# Splitting data (train: 0.7, val: 0.15, test: 0.15)...
#
# Dataset split:
#   Train: 778 samples (Pos: 391, Neg: 387)
#   Val:   167 samples (Pos: 84, Neg: 83)
#   Test:  167 samples (Pos: 84, Neg: 83)
#
# ✓ Combined data saved to results/combined_data
#   - train_data.pkl
#   - val_data.pkl
#   - test_data.pkl
#
#
# ...
# Configuration
# ...
#   train_file                : results/combined_data/train_data.pkl
#   val_file                  : results/combined_data/val_data.pkl
#   test_file                 : results/combined_data/test_data.pkl
# ...

# %%
import pickle
import os
# Check one file
fs = os.listdir("gin_results/organized_data/CWE-119_CVE2019-1")
for file in fs:
    with open(f'gin_results/organized_data/CWE-119_CVE2019-1/{file}', 'rb') as f:
        data = pickle.load(f)
        print(type(data))
        print(data.keys() if isinstance(data, dict) else f"List of length {len(data)}")
# Out:
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 4
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 1
# <class 'list'>
# List of length 2
# <class 'list'>
# ...
